# %%
from PIL import Image
from PIL import ImageDraw
import os
import argparse

import numpy as np

print(Image.__version__)
# Out:
# 7.1.2

# %%
_img = Image.open('../res/shally.jpg')

print(_img.size)
print(_img.size[0])
_img
# display()
# Out:
# (1281, 720)
# 1281
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=1281x720 at 0x7FD4AF7F8290>

# %%
# print(800*_img.size[0])
_ratio = 800/_img.size[0]

print(_ratio)

_size = (int(_img.size[0] * _ratio),int(_img.size[1] * _ratio))

print(_size)
_img_resized = _img.resize( _size,Image.ANTIALIAS)

_img_resized
# Out:
# 0.624512099921936
# (800, 449)
# <PIL.Image.Image image mode=RGB size=800x449 at 0x7FD4B102DC10>

# %%
_imgout = Image.new(mode='RGB',size=(800,600),color=(255,0,0))

_imgout.paste(_img_resized)

_imgout
# Out:
# <PIL.Image.Image image mode=RGB size=800x600 at 0x7FD4AF82B810>
