# %% [markdown]
# ## pillow 예제
#
# 설치하기
# ``` bash
# pip install Pillow
# ```
#
# 공식문서 [https://pillow.readthedocs.io/en/stable/]

# %%
from PIL import Image
from PIL import ImageDraw
from IPython.display import display
import numpy as np
import sys

print(sys.version)
# Out:
# 3.7.7 (default, Mar 26 2020, 10:32:53)
# [Clang 4.0.1 (tags/RELEASE_401/final)]

# %%
image = Image.open('./res/2.jpg')
image_np = np.array(image)


print( type(image))
print(image_np.shape)
print(image.size)
print(image.format)
print(image.mode)

display(image)
# Out:
# <class 'PIL.JpegImagePlugin.JpegImageFile'>
# (512, 768, 3)
# (768, 512)
# JPEG
# RGB
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=768x512 at 0x113E24590>

# %%
copyImg = image.copy()
draw = ImageDraw.Draw(copyImg)
draw.line((100,100,250,200),fill='red',width=8)

display(copyImg)
# Out:
# <PIL.Image.Image image mode=RGB size=768x512 at 0x123469A90>
